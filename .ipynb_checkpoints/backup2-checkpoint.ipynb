# %%
import numpy as np
import pandas as pd

data = pd.read_csv("/home/leon/Desktop/market/data/vector_data_ratings.csv")

# %%
from matplotlib import pyplot as plt
from scipy.cluster.hierarchy import dendrogram, linkage

# %%
sum([np.isnan(x) for x in data.values.sum(axis=1)])
# Out:
# 1

# %%
data = data.iloc[:-1,1:]

# %%
Z = linkage(data.values, 'complete', 'cityblock')

# %%
plt.figure(figsize=(25, 10))
plt.title('Hierarchical Clustering Dendrogram')
plt.xlabel('sample index')
plt.ylabel('distance')
dendrogram(
    Z,
    leaf_rotation=90.,  # rotates the x axis labels
    leaf_font_size=12.,  # font size for the x axis labels
)
plt.show()

# %%
plt.figure(figsize=(25, 10))
plt.title('Hierarchical Clustering Dendrogram')
plt.xlabel('sample index')
plt.ylabel('distance')
dendrogram(
    Z,
    truncate_mode='lastp',  # show only the last p merged clusters
    p=6,  # show only the last p merged clusters
    show_leaf_counts=True,
    leaf_rotation=90.,  # rotates the x axis labels
    leaf_font_size=12.,  # font size for the x axis labels
)
plt.show()

# %%
Z[-10:, 2]
# Out:
# array([182.3067931 , 189.83588382, 197.336566  , 201.49918343,
#        205.80621556, 242.9218326 , 264.501836  , 270.7807843 ,
#        289.3934223 , 366.63990405])

# %%
last = Z[-10:, 2]
last_rev = last[::-1]
idxs = np.arange(1, len(last) + 1)
plt.plot(idxs, last_rev)

acceleration = np.diff(last, 2)  # 2nd derivative of the distances
acceleration_rev = acceleration[::-1]
plt.plot(idxs[:-2] + 1, acceleration_rev)
plt.show()

k = acceleration_rev.argmax() + 2  # if idx 0 is the max of this we want 2 clusters
print("clusters:{}".format(k))
# Out:
# clusters:2

# %%
from scipy.cluster.hierarchy import fcluster
k = 7
cluster = fcluster(Z, k, criterion='maxclust')

# %%
cluster = pd.DataFrame(cluster)

data = pd.concat([data, cluster], axis=1)

# %%
cluster_data = []
for x in np.arange(1,k+1):
    cluster_data += [data[data.iloc[:,-1] == x]]

# %%
[(np.mean(x.iloc[:,0])/30, x.shape[0]) for x in cluster_data]
# Out:
# [(4.491941982272361, 2482),
#  (1.6551724137931034, 406),
#  (4.909889094269871, 2164),
#  (3.9390243902439024, 82),
#  (3.0, 2),
#  (2.8310344827586205, 290),
#  (1.2097902097902098, 143)]

# %%
cluster_max = [np.amax(x, axis=0) for x in cluster_data]
cluster_mean = [np.mean(x, axis=0) for x in cluster_data]

# %%
for x in np.arange(k):
    cluster_max[x].iloc[:50] = cluster_mean[x].iloc[:50]

# %%
len(cluster_max)
# Out:
# 7

# %%
def cosine_similarity(a,b):
    return(a.dot(b.T)/(np.sqrt((a**2).sum()) * np.sqrt((b**2).sum())))

# %%
from scipy.spatial.distance import cityblock

# %%
for x in np.arange(k):
    #cluster_data[x] = cluster_data[x].iloc[:,:-1]
    print(cluster_data[x].shape)
    sims = []
    for index, row in cluster_data[x].iterrows():
        sims.append(cityblock(row.values[49:], cluster_max[x][49:]))
    
    cluster_data[x]["similarity"] = sims
# Out:
# (2482, 302)
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# (406, 302)
# (2164, 302)
# (82, 302)
# (2, 302)
# (290, 302)
# (143, 302)

# %%
import json
with open("/home/leon/Desktop/market/data/all_data2.json", "r") as f:
    review_list = json.load(f)

# %%
example_reviews = []
for x in np.arange(k):
    example_index = np.argmin(cluster_data[x]["similarity"])
    print(example_index)
    example_reviews += [review_list["reviews"][example_index]]
# Out:
# 4557
# 576
# 3463
# 534
# 452
# 1119
# 3742
# /usr/local/lib/python3.5/dist-packages/numpy/core/fromnumeric.py:52: FutureWarning: 'argmin' is deprecated, use 'idxmin' instead. The behavior of 'argmin'
# will be corrected to return the positional minimum in the future.
# Use 'series.values.argmin' to get the position of the minimum now.
#   return getattr(obj, method)(*args, **kwds)

# %%
example_reviews
# Out:
# [{'review_author': '',
#   'review_comment_count': '',
#   'review_header': 'Odd, but refreshing.',
#   'review_posted_date': '04 Feb 2016',
#   'review_rating': '4.0 ',
#   'review_text': "Odd, but refreshing. When I very first put it on, I wasn't super impressed or anything. But as I let it sit it got more bubbly and it feels quite nice. Just a very gentle tingle and cooling sensation."},
#  {'review_author': '',
#   'review_comment_count': '',
#   'review_header': 'One Star',
#   'review_posted_date': '12 Nov 2016',
#   'review_rating': '1.0 ',
#   'review_text': 'Instructions not in English'},
#  {'review_author': '',
#   'review_comment_count': '',
#   'review_header': 'I Love the Fizz!',
#   'review_posted_date': '01 Jun 2016',
#   'review_rating': '5.0 ',
#   'review_text': "I love this mask! The consistency of the clay mask was gooey, but felt great on my skin, next thing I know, it starts to fizz on my face, it felt really good like my skin was getting clean in a way that scrubs wish they could do! My face is softer to the touch and I can't wait to use it again. The seal was a bit difficult to open, but other than that, a real easy to use product."},
#  {'review_author': '',
#   'review_comment_count': '',
#   'review_header': 'Four Stars',
#   'review_posted_date': '27 May 2017',
#   'review_rating': '4.0 ',
#   'review_text': 'It really works my face skin lightened so the blemishes.'},
#  {'review_author': '',
#   'review_comment_count': '',
#   'review_header': 'One Star',
#   'review_posted_date': '03 Feb 2016',
#   'review_rating': '1.0 ',
#   'review_text': 'Made my face break out REALLY bad'},
#  {'review_author': '',
#   'review_comment_count': '',
#   'review_header': 'Fun facemask but probably not the most effective',
#   'review_posted_date': '08 Nov 2016',
#   'review_rating': '3.0 ',
#   'review_text': "It was fun to try. Bubbles were huge! However, I'm unsure of how much it actually did. Left my face a little pink but no noticable difference looking at my pores."},
#  {'review_author': '',
#   'review_comment_count': '',
#   'review_header': 'I was very excited to use it after reading all these amazing reviews. Very',
#   'review_posted_date': '27 Feb 2018',
#   'review_rating': '1.0 ',
#   'review_text': "It burns every time I used it. I don't know if it was just me. I was very excited to use it after reading all these amazing reviews. Very sad"}]

# %%
cluster_reviews = []
for x in np.arange(k):
    reviews_index = list(cluster_data[x].index)
    cluster_reviews += [[review_list["reviews"][x] for x in reviews_index]]

# %%
[len(x) for x in cluster_reviews]
# Out:
# [2482, 406, 2164, 82, 2, 290, 143]

# %%
cluster_reviews[4][:10]
# Out:
# [{'review_author': '',
#   'review_comment_count': '',
#   'review_header': 'One Star',
#   'review_posted_date': '03 Feb 2016',
#   'review_rating': '1.0 ',
#   'review_text': 'Made my face break out REALLY bad'},
#  {'review_author': '',
#   'review_comment_count': '',
#   'review_header': 'Five Stars',
#   'review_posted_date': '31 Mar 2017',
#   'review_rating': '5.0 ',
#   'review_text': 'Very good mask!'}]

# %%
[(np.mean(x.iloc[:,0]), x.shape[0]) for x in cluster_data]

# %%
example_reviews
